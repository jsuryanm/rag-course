# %%
import os
import warnings
from pathlib import Path
from datetime import datetime

# Suppress warnings for cleaner output
warnings.filterwarnings('ignore')

# Environment variables
from dotenv import load_dotenv

# LangChain core imports (LCEL patterns)
from langchain_core.documents import Document
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser
from langchain_core.runnables import RunnablePassthrough

# LangChain components
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_openai import OpenAIEmbeddings, ChatOpenAI
from langchain_community.vectorstores import FAISS

# Ragas evaluation framework (updated for 0.3.7)
from ragas import evaluate, EvaluationDataset, SingleTurnSample
from ragas.metrics import (
    Faithfulness,
    AnswerRelevancy,
    ContextPrecision,
    ContextRecall,
    ContextEntityRecall,
    NoiseSensitivity,
)
# Ragas LangChain integration wrappers (required for 0.3.9)
from ragas.llms import LangchainLLMWrapper
from ragas.embeddings import LangchainEmbeddingsWrapper

# HuggingFace datasets for Ragas
from datasets import Dataset

# OPIK for experiment tracking and observability
try:
    import opik
    from opik import track, Opik
    OPIK_AVAILABLE = True
    print("✓ OPIK available for experiment tracking")
except ImportError:
    OPIK_AVAILABLE = False
    print("ℹ OPIK not installed. Install with: pip install opik")

# Visualization libraries
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 24
#      20 from langchain_openai import OpenAIEmbeddings, ChatOpenAI
#      21 from langchain_community.vectorstores import FAISS
#      22
#      23 # Ragas evaluation framework (updated for 0.3.7)
# ---> 24 from ragas import evaluate, EvaluationDataset, SingleTurnSample
#      25 from ragas.metrics import (
#      26     Faithfulness,
#      27     AnswerRelevancy,
#
# File c:\Users\rsurs\OneDrive\Documents\Root\rag-course\.venv\Lib\site-packages\ragas\__init__.py:3
#       1 from ragas.cache import CacheInterface, DiskCacheBackend, cacher
#       2 from ragas.dataset_schema import EvaluationDataset, MultiTurnSample, SingleTurnSample
# ----> 3 from ragas.evaluation import evaluate
#       4 from ragas.run_config import RunConfig
#       6 try:
#
# File c:\Users\rsurs\OneDrive\Documents\Root\rag-course\.venv\Lib\site-packages\ragas\evaluation.py:28
#      26 from ragas.executor import Executor
#      27 from ragas.integrations.helicone import helicone_config
# ---> 28 from ragas.llms import llm_factory
#      29 from ragas.llms.base import BaseRagasLLM, LangchainLLMWrapper
#      30 from ragas.metrics import AspectCritic
#
# File c:\Users\rsurs\OneDrive\Documents\Root\rag-course\.venv\Lib\site-packages\ragas\llms\__init__.py:1
# ----> 1 from ragas.llms.base import (
#       2     BaseRagasLLM,
#       3     LangchainLLMWrapper,
#       4     LlamaIndexLLMWrapper,
#       5     llm_factory,
#       6 )
#       7 from ragas.llms.haystack_wrapper import HaystackLLMWrapper
#       9 __all__ = [
#      10     "BaseRagasLLM",
#      11     "HaystackLLMWrapper",
#    (...)     14     "llm_factory",
#      15 ]
#
# File c:\Users\rsurs\OneDrive\Documents\Root\rag-course\.venv\Lib\site-packages\ragas\llms\base.py:8
#       5 from abc import ABC, abstractmethod
#       6 from dataclasses import dataclass, field
# ----> 8 from langchain_community.chat_models.vertexai import ChatVertexAI
#       9 from langchain_community.llms import VertexAI
#      10 from langchain_core.language_models import BaseLanguageModel
#
# ModuleNotFoundError: No module named 'langchain_community.chat_models.vertexai'
